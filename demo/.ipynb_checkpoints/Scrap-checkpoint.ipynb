# %%
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()

# div1=driver.find_elements_by_xpath("/html[1]/body[1]/div[1]/div[1]/div[4]/div[1]/div[2]/div[2]/div[1]/div[2]/div[1]/div[5]/div[1]/div[1]/dl[1]/div[2]")
# # n=div1.find_element_by_class_name("type__h3").text
# n=div1.find_element_by_xpath("//dd[@class='type__h3']/a'")
# print(n.get_attribute("text"))
# WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[1]/div[3]/p[1]/button[1]"))).click()
# driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[1]/div[3]/p[1]/button[1]").click()

driver.find_element_by_xpath("//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')]").click()

# nxt=driver.find_element_by_xpath("//*[contains(@class,'card-lister-cta__viewAllLink--35010235 type__eyebrow')]")
nxt=driver.find_element_by_xpath("//button[@class='card-lister-cta__viewAllLink--35010235 type__eyebrow']")
nxt.click()
time.sleep(2)
for i in range(1,10):
    name=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))
    mail=driver.find_element_by_xpath("(//*[contains(@class, 'color-dodger-blue hover-color-light-navy')])[%d]"%(i))
    tel=driver.find_element_by_xpath("//a[@class='color-light-navy hover-color-dodger-blue']")

    practice=driver.find_element_by_xpath("(//*[contains(@class, 'hover-color-light-navy color-dodger-blue')])[%d]"%(i))
    print(name.text)
    print(mail.text)
    print(tel.text)
    print(practice.text)
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# Michael P. Addis
# maddis@cravath.com
# +1-212-474-1956
# LITIGATION
# Lauren Angelilli
# langelilli@cravath.com
# +1-212-474-1956
# TAX
# Craig F. Arcella
# carcella@cravath.com
# +1-212-474-1956
# CORPORATE
# Michael L. Arnold
# marnold@cravath.com
# +1-212-474-1956
# CORPORATE
# Peter T. Barbur
# pbarbur@cravath.com
# +1-212-474-1956
# LITIGATION
# Robert H. Baron
# rbaron@cravath.com
# +1-212-474-1956
# LITIGATION
# Heather A. Benjamin
# hbenjamin@cravath.com
# +1-212-474-1956
# TRUSTS AND ESTATES
# D. Scott Bennett
# sbennett@cravath.com
# +1-212-474-1956
# CORPORATE
# Matthew J. Bobby
# mbobby@cravath.com
# +1-212-474-1956
# EXECUTIVE COMPENSATION AND BENEFITS

# %%
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
# print(driver.title)
# print(driver.current_url)
driver.maximize_window()


driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click()

driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[1]/div[3]/p[1]/button[1]").click()
time.sleep(2)
q=1
while(q!=5):
    count_of_divs = len(driver.find_elements_by_xpath("(//*[contains(@class, 'card-lister__box--554421f0')])"))
   
    for i in range(1,count_of_divs):
        name=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))
        print(name.text)
#         mail=driver.find_element_by_xpath("(//*[contains(@class, 'color-dodger-blue hover-color-light-navy')])[%d]"%(i))
#         print(mail.text)
#         tel=driver.find_element_by_xpath("//a[@class='color-light-navy hover-color-dodger-blue']")
#         print(tel.text)
#         practice=driver.find_element_by_xpath("(//*[contains(@class, 'hover-color-light-navy color-dodger-blue')])[%d]"%(i))
#         print(practice.text)
    driver.find_element_by_xpath("(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").click()
    time.sleep(3)
    q+=1
    
time.sleep(2)  
driver.find_element_by_xpath("//li//following::a[contains(text(),'People')][1]").click() 
time.sleep(2)  
# driver.get("https://www.cravath.com/people/index.html")
# ofcounsel
print("*********************")
driver.find_element_by_xpath(" //body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[2]/div[3]/p[1]/button[1]").click()  
time.sleep(2)   
for i in range(1,8):
        cname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
        print(cname.text)
# Out:
# Michael P. Addis
# Lauren Angelilli
# Craig F. Arcella
# Michael L. Arnold
# Peter T. Barbur
# Robert H. Baron
# Heather A. Benjamin
# D. Scott Bennett
# Matthew J. Bobby
# Philip J. Boeckman
# Gary A. Bornstein
# John D. Buretta
# Stephen L. Burns
# Timothy G. Cameron
# Alyssa K. Caples
# Daniel J. Cerqueira
# Ting S. Chen
# Evan R. Chesler
# Justin C. Clarke
# Ronald E. Creamer Jr.
# Karin A. DeMasi
# Alexandra C. Denning
# Nicholas A. Dorsey
# Thomas E. Dunn
# Wes Earnhardt
# Andrew C. Elken
# Yonatan Even
# Christopher K. Fargo
# David S. Finkelstein
# William V. Fogg
# Hon. Katherine B. Forrest (fmr.)
# Helam Gebremariam
# Michael S. Goldman
# Stephen L. Gordon
# Sharonmoyee Goswami
# Mark I. Greene
# Aaron M. Gruber
# Benjamin Gruenstein
# Richard Hall
# O. Keith Hallam III
# Damaris Hernández
# Eric W. Hilfers
# Jenny Hochenberg
# Keith R. Hummel
# Matthew G. Jones
# David J. Kappos
# Jonathan J. Katz
# Matthew M. Kelly
# Lauren Roberta Kennedy
# Stephen M. Kessing
# ...

# %%
SENIOR ATTORNEY

# %%
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()


driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click() 

driver.find_element_by_xpath(" //body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[4]/div[3]/p[1]/button[1]").click()  
time.sleep(2)   
for i in range(1,20):
        Ecname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
        print(Ecname.text)
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# Elizabeth Albert
# Isaac C. Beerman
# Brent Byars
# Joseph L. Calamari
# Abigail C. Caponetti
# Andrew Carlon
# Ralph B. Currey III
# Scott J. Ferretti
# Joanne M. Gentile
# Will C. Giles
# Jody A. Healy
# Joyce Law
# R. Kirkie Maswoswe
# Sarah F. Rosen
# Danielle C. Segal
# Kiran Sheffrin
# Paul D. Siniawer
# Annmarie M. Terraciano
# Jesse M. Weiss

# %%
PRACTICE AREA ATTORNEY

# %%
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()


driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click() 

driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[5]/div[3]/p[1]/button[1]").click()  
time.sleep(4)   
for i in range(1,10):
        sname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
        print(sname.text)
#         edu=driver.find_element_by_xpath("(//h3[contains(text(),'Education')]//following::li[1])")
#         edu=driver.find_element_by_xpath("//li[contains(@class,'bullet')]//following::li[1]")
#         edu=driver.find_element_by_xpath("//li[@class='bullet']//following::div[@xpath='1']")
#         print(edu.text)
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# Tatiana N. Alyonycheva
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6640/1753785091.py in <module>
#      24 #         edu=driver.find_element_by_xpath("(//h3[contains(text(),'Education')]//following::li[1])")
#      25 #         edu=driver.find_element_by_xpath("//li[contains(@class,'bullet')]//following::li[1]")
# ---> 26         edu=driver.find_element_by_xpath("//li[@class='bullet']//following::div[@xpath='1']")
#      27         print(edu.text)
#
# c:\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
# ...

# %%
ASSOCIATE/LAW CLERK

# %%
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()


driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click() 

driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[8]/div[3]/p[1]/button[1]").click()  
time.sleep(4)   
for i in range(1,10):
        aname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
        print(aname.text)
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# Vanessa S. Ajagu
# Solomon Akesseh
# Cesar Albinana
# J. Elizabeth Allan
# Safaa Aly
# Margaret E. Anderson
# Virginia M. Anderson
# Benjamin B. Arcano
# Oluwatumise Asebiomo

# %%
#SENIOR DISCOVERY ATTORNEY
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()

driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click() 

driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[9]/div[3]/p[1]/button[1]").click()  
time.sleep(4) 
for i in range(1,16):
    LCname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
    print(LCname.text)
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# James E. Canning
# J.D., University of Pennsylvania Law School
# Brian Chang
# J.D., University of Pennsylvania Law School
# Stéphane P. Des Lauriers
# J.D., University of Pennsylvania Law School
# Raffaele DiMaggio
# J.D., University of Pennsylvania Law School
# Robert B. Galvin
# J.D., University of Pennsylvania Law School
# Erica Gerlando
# J.D., University of Pennsylvania Law School
# Thomas M. Gorman
# J.D., University of Pennsylvania Law School
# Joel Hagood
# J.D., University of Pennsylvania Law School
# Alysa D. Mokas
# J.D., University of Pennsylvania Law School
# Jeremee Pecache
# J.D., University of Pennsylvania Law School
# Marlene Denise Sharpe
# J.D., University of Pennsylvania Law School
# Joachim F. Trautmann
# J.D., University of Pennsylvania Law School
# John D. Viruet
# J.D., University of Pennsylvania Law School
# David Viscomi
# J.D., University of Pennsylvania Law School
# ...

# %%
#RETIRED PARTNER
import selenium
from selenium import webdriver
import pandas as pd

from selenium.webdriver.support.ui import Select
import time
import  os

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()

driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click() 

driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[11]/div[3]/p[1]/button[1]").click()  
time.sleep(4) 
q=1
while(q!=3):
    count_of_divs = len(driver.find_elements_by_xpath("(//*[contains(@class, 'card-lister__box--554421f0')])"))
    for i in range(1,count_of_divs):
        LCname=driver.find_element_by_xpath("(//*[contains(@class, 'type__h3')])[%d]"%(i))  
        print(LCname.text)
        time.sleep(3)
    driver.find_element_by_xpath("(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").click()
    time.sleep(3)
    q+=1
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# Richard M. Allen
# Francis P. Barron
# Melvin L. Bedrick
# John E. Beerbower
# Douglas D. Broadwater
# Thomas R. Brome
# Roger G. Brooks
# David O. Brownwood
# Herbert L. Camp
# Richard W. Clary
# James D. Cooper
# Benjamin F. Crane
# Paul M. Dodyk
# LizabethAnn R. Eisen
# Allen Finkelson
# Philip A. Gelston
# Stuart W. Gold
# David Greenwald
# Kevin J. Grehan
# Alan J. Hruska
# B. Robbins Kiessling
# Collier Kirkham
# Stephen S. Madsen
# Rory O. Millson
# David G. Ormsby
# Thomas G. Rafferty
# Robert S. Rifkind
# William P. Rogers Jr.
# Ronald S. Rolfe
# Marc S. Rosenberg
# Paul C. Saunders
# Frederick A. O. Schwarz Jr.
# Martin L. Senzel
# Gregory M. Shaw
# Max R. Shulman
# Alan C. Stephenson
# Roger D. Turner
# James C. Vardell III

# %%
# no view categories

# %%
import selenium
from selenium import webdriver
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from selenium.webdriver.support.ui import Select
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import  os
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_experimental_option("prefs", {"profile.block_third_party_cookies": True})
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()


driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click()
# driver.find_element_by_xpath("//body/div[@id='app']/div[1]/div[4]/div[1]/div[2]/div[2]/div[1]/div[3]/p[1]/button[1]").click()

time.sleep(3)
a = driver.find_elements_by_class_name("l-vgap-generic-interior-section")
# tab=driver.find_elements_by_xpath("//*[@class='l-vgap-generic-interior-section']")
print(len(a))
# for i in range(0,len(a)):
#     try:
#
#         if(a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce")):
#             # print("yes")
#             # name=a[i].find_element_by_class_name("type__h3")
#
#             # print(name.text)
#             a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce").click()
#             time.sleep(5)
#             names = a[i].find_elements_by_class_name("type__h3")
#             for j in range(0, len(names)):
#                 # name = a[i].find_element_by_class_name("type__h3")
#                 print(names[j].text)
#             driver.find_element_by_xpath('//a[contains(@href,"https://www.cravath.com/people/index.html")]').click()
#             time.sleep(5)
#
#     except NoSuchElementException or StaleElementReferenceException:
#
#         print("------------------")
#         names = a[i].find_elements_by_class_name("type__h3")
#         for j in range(0,len(names)):
#             # name = a[i].find_element_by_class_name("type__h3")
#             print(names[j].text)
#     time.sleep(3)
# [<selenium.webdriver.remote.webelement.WebElement (session="c277817003d8f3e39959aa9f02484228", element="8b0e1f7f-c0e0-4c3b-b0b1-e82a9c3ba80c")>]
#
for i in range(0,len(a)):
    try:

        if(a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce")):
            # print("yes")
            # name=a[i].find_element_by_class_name("type__h3")
            pass
            # print(name.text)
            # a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce").click()
            # time.sleep(5)
            # names = a[i].find_elements_by_class_name("type__h3")
            # for j in range(0, len(names)):
            #     # name = a[i].find_element_by_class_name("type__h3")
            #     print(names[j].text)
            # driver.find_element_by_xpath('//a[contains(@href,"https://www.cravath.com/people/index.html")]').click()
            # time.sleep(5)

    except:
        print("------------------")
        names = a[i].find_elements_by_class_name("type__h3")
        for j in range(0,len(names)):
            # name = a[i].find_element_by_class_name("type__h3")
            print(names[j].text)
    time.sleep(3)

# for i in range(0,len(a)):
#     try:
#
#         if(a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce")):
#             # print("yes")
#             # name=a[i].find_element_by_class_name("type__h3")
#
#             # print(name.text)
#             a[i].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce").click()
#             time.sleep(5)
#             names = a[i].find_elements_by_class_name("type__h3")
#             for j in range(0, len(names)):
#                 # name = a[i].find_element_by_class_name("type__h3")
#                 print(names[j].text)
#             driver.find_element_by_xpath('//a[contains(@href,"https://www.cravath.com/people/index.html")]').click()
#             time.sleep(5)
#             print(i)
#     except:
#         pass
#
#
#
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# 13
# ------------------
# Roberto Bruno
# Virginie Marier
# Margaret R. M. Rallings
# ------------------
# Scott B. Reents
# ------------------
# Deborah J. Yu
# ------------------
# Samuel C. Butler
# ------------------
# Sarah S. B. Kessler
# ------------------
# Sophia D. Tawil
